# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0           leer  53.2316    7.4610     18.86        90         100
# 1        1       waitangi -43.9535 -176.5597     12.68        90          17
# 2        2      hithadhoo  -0.6000   73.0833     27.86        73          46
# 3        3       qaqortoq  60.7167  -46.0333      3.05        82         100
# 4        4  kriva palanka  42.2019   22.3319     12.36        87          56
#
#    Wind Speed Country        Date
# 0        3.31      DE  1696187597
# 1        2.24      NZ  1696187597
# 2        6.00      MV  1696187419
# 3        2.14      GL  1696187597
# 4        2.35      MK  1696187597

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    color = "City",
    frame_width = 800,
    frame_height = 600,
    title = f"City's Humidity (10/1/23)")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df[(city_data_df["Max Temp"] >= 18) & (city_data_df["Max Temp"] < 29) & 
                        (city_data_df["Cloudiness"] >= 10) & (city_data_df["Cloudiness"] < 65) &
                        (city_data_df["Wind Speed"] < 5)]

# Drop any rows with null values
ideal_df = ideal_df.dropna(how="any")

# Display sample data
ideal_df.head()
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 7         7     jamestown  42.0970  -79.2353     24.73        62          20
# 17       17        saipan  15.1355  145.7010     27.39        94          20
# 22       22       mersing   2.4312  103.8405     23.95        94          20
# 38       38  mont-laurier  46.5501  -75.4993     21.79        63          33
# 47       47      portland  45.5234 -122.6762     19.41        65          20
#
#     Wind Speed Country        Date
# 7         4.63      US  1696187483
# 17        2.06      MP  1696187400
# 22        3.09      MY  1696187598
# 38        1.53      CA  1696187475
# 47        2.06      US  1696187376

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 7      jamestown      US  42.0970  -79.2353        62
# 17        saipan      MP  15.1355  145.7010        94
# 22       mersing      MY   2.4312  103.8405        94
# 38  mont-laurier      CA  46.5501  -75.4993        63
# 47      portland      US  45.5234 -122.6762        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories" : "acommodation.hotel", 
    "limit" : 20,
    "apikey" : geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# jamestown - nearest hotel: No hotel found
# saipan - nearest hotel: No hotel found
# mersing - nearest hotel: No hotel found
# mont-laurier - nearest hotel: No hotel found
# portland - nearest hotel: No hotel found
# mugia - nearest hotel: No hotel found
# bikenibeu village - nearest hotel: No hotel found
# kavieng - nearest hotel: No hotel found
# mushie - nearest hotel: No hotel found
# pervomays'kyy - nearest hotel: No hotel found
# gbadolite - nearest hotel: No hotel found
# fort bragg - nearest hotel: No hotel found
# vila velha - nearest hotel: No hotel found
# andergrove - nearest hotel: No hotel found
# la passe - nearest hotel: No hotel found
# cinisi - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: No hotel found
# hadibu - nearest hotel: No hotel found
# arnprior - nearest hotel: No hotel found
# bel ombre - nearest hotel: No hotel found
# camana - nearest hotel: No hotel found
# fale old settlement - nearest hotel: No hotel found
# palmer - nearest hotel: No hotel found
# shuangjiang - nearest hotel: No hotel found
# lorengau - nearest hotel: No hotel found
# georgetown - nearest hotel: No hotel found
# shimoda - nearest hotel: No hotel found
# axim - nearest hotel: No hotel found
# pangkalpinang - nearest hotel: No hotel found
# howrah - nearest hotel: No hotel found
# mermoz boabab - nearest hotel: No hotel found
# vila franca do campo - nearest hotel: No hotel found
# bowen - nearest hotel: No hotel found
# tofol - nearest hotel: No hotel found
# atafu village - nearest hotel: No hotel found
# saint-felicien - nearest hotel: No hotel found
# lata - nearest hotel: No hotel found
# zango - nearest hotel: No hotel found
# alo - nearest hotel: No hotel found
# alice springs - nearest hotel: No hotel found
# waingapu - nearest hotel: No hotel found
# macas - nearest hotel: No hotel found
# mbanza-ngungu - nearest hotel: No hotel found
# darwin - nearest hotel: No hotel found
# tamanrasset - nearest hotel: No hotel found
# kuta - nearest hotel: No hotel found
# palikir - national government center - nearest hotel: No hotel found
# miri - nearest hotel: No hotel found
# luanda - nearest hotel: No hotel found
# benguela - nearest hotel: No hotel found
# behshahr - nearest hotel: No hotel found
# antsiranana - nearest hotel: No hotel found
# rantepao - nearest hotel: No hotel found
# esmeraldas - nearest hotel: No hotel found
# viqueque - nearest hotel: No hotel found
# kununurra - nearest hotel: No hotel found
# ozu - nearest hotel: No hotel found
# ypsonas - nearest hotel: No hotel found
# st. john's - nearest hotel: No hotel found
# machico - nearest hotel: No hotel found
# corner brook - nearest hotel: No hotel found
# kayangel - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity      Hotel Name
# 7       jamestown      US  42.0970  -79.2353        62  No hotel found
# 17         saipan      MP  15.1355  145.7010        94  No hotel found
# 22        mersing      MY   2.4312  103.8405        94  No hotel found
# 38   mont-laurier      CA  46.5501  -75.4993        63  No hotel found
# 47       portland      US  45.5234 -122.6762        65  No hotel found
# ..            ...     ...      ...       ...       ...             ...
# 538       ypsonas      CY  34.6884   32.9574        83  No hotel found
# 554    st. john's      CA  47.5649  -52.7093        62  No hotel found
# 563       machico      PT  32.7000  -16.7667        80  No hotel found
# 572  corner brook      CA  48.9667  -57.9484        62  No hotel found
# 576      kayangel      PW   8.0823  134.7173        81  No hotel found
#
# [62 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    tiles = "EsriNatGeo", 
    color= "City", 
    line_color="black", 
    size=80, 
    frame_width=800, 
    frame_height=600, 
    hover_cols = ["Humidity","Hotel Name", "Country" ],
    title=f"Hotels within 10,000 meters (10/1/23)"
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
